# %% [markdown]
# # Project : Computer Vision Anomally Detecting

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install timm
# Out:
# Collecting timm
#   Downloading timm-0.5.4-py3-none-any.whl (431 kB)
#      |████████████████████████████████| 431 kB 34.7 MB/s
# Requirement already satisfied: torch>=1.4 in /usr/local/lib/python3.7/dist-packages (from timm) (1.11.0+cu113)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.7/dist-packages (from timm) (0.12.0+cu113)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.4->timm) (4.2.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torchvision->timm) (1.21.6)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.7/dist-packages (from torchvision->timm) (7.1.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from torchvision->timm) (2.23.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision->timm) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision->timm) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision->timm) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision->timm) (2021.10.8)
# Installing collected packages: timm
# Successfully installed timm-0.5.4

# %% [markdown]
# ## Settings

# %%
import warnings
warnings.filterwarnings('ignore')

from glob import glob
import pandas as pd
import numpy as np 
from tqdm import tqdm
import cv2

import os
import timm
import random

import torch
from torch.utils.data import Dataset, DataLoader
import torch.nn as nn
import torchvision.transforms as transforms
from sklearn.metrics import f1_score, accuracy_score
import time

from sklearn.model_selection import StratifiedKFold
device = torch.device('cuda')

# %% [markdown]
# ## Data load

# %%
path = './'

# %%
train_png = sorted(glob(path + 'data/train/*.png'))
test_png = sorted(glob(path + 'data/test/*.png'))

# %% [markdown]
# glob : 많은 파일들을 다뤄야 하는 파이썬 프로그램을 작성할 때, 특정한 패턴이나 확장자를 가진 파일들의 경로나 이름이 필요할 때가 있다. glob 모듈의 glob 함수는 사용자가 제시한 조건에 맞는 파일명을 리스트 형식으로 반환한다.

# %%
len(train_png), len(test_png)

# %%
# class 속성에 필요한 label을 수집하는 부분
# df의 label 과 class를 추출하였다.

train_y = pd.read_csv(path +"data/train_df.csv")

train_labels = train_y["label"]
train_classes = train_y['class']

label_unique = sorted(np.unique(train_labels))
label_unique = {key:value for key,value in zip(label_unique, range(len(label_unique)))}
class_unique = sorted(np.unique(train_classes))
class_unique = {key:value for key,value in zip(class_unique, range(len(class_unique)))}

train_labels = [label_unique[k] for k in train_labels]
train_classes = [class_unique[k] for k in train_classes]

# %%
# img resize

def img_load(path):
    img = cv2.imread(path)[:,:,::-1]
    img = cv2.resize(img, (384, 384),interpolation = cv2.INTER_AREA)
    return img

# %%
# glob으로 만들었던 이미지 file 이름 list를 사용하여 load하고 리스트를 만든다.

train_imgs = [img_load(m) for m in tqdm(train_png)]
test_imgs = [img_load(n) for n in tqdm(test_png)]
# Out:
# 100%|███████████████████████████████████████| 4277/4277 [02:04<00:00, 34.43it/s]
# 100%|███████████████████████████████████████| 2154/2154 [01:02<00:00, 34.61it/s]

# %%
# 위에서 만든 이미지 리스트를 npy 형식으로 저장한다.

np.save(path + 'data/train_imgs_384', np.array(train_imgs))
np.save(path + 'data/test_imgs_384', np.array(test_imgs))

# %%
# 저장한 이미지를 불러온다

train_imgs = np.load(path + 'data/train_imgs_384.npy')
test_imgs = np.load(path + 'data/test_imgs_384.npy')

# %%
# RGB 평균((384, 384, 3) => (3)) 리스트
# 리스트의 각 RGB별 평균을 내서 사용

meanRGB = [np.mean(x, axis=(0,1)) for x in train_imgs]
stdRGB = [np.std(x, axis=(0,1)) for x in train_imgs]

meanR = np.mean([m[0] for m in meanRGB])/255
meanG = np.mean([m[1] for m in meanRGB])/255
meanB = np.mean([m[2] for m in meanRGB])/255

stdR = np.mean([s[0] for s in stdRGB])/255
stdG = np.mean([s[1] for s in stdRGB])/255
stdB = np.mean([s[2] for s in stdRGB])/255

print("train 평균",meanR, meanG, meanB)
print("train 표준편차",stdR, stdG, stdB)

# train 평균 0.4330380901867049 0.4034575319032911 0.39415050509784405
# train 표준편차 0.1815717110252788 0.17403455556798705 0.16323395055036488
# Out:
# train 평균 0.4330380901867049 0.4034575319032911 0.39415050509784405
# train 표준편차 0.1815717110252788 0.17403455556798705 0.16323395055036488

# %%
meanRGB = [np.mean(x, axis=(0,1)) for x in test_imgs]
stdRGB = [np.std(x, axis=(0,1)) for x in test_imgs]

meanR = np.mean([m[0] for m in meanRGB])/255
meanG = np.mean([m[1] for m in meanRGB])/255
meanB = np.mean([m[2] for m in meanRGB])/255

stdR = np.mean([s[0] for s in stdRGB])/255
stdG = np.mean([s[1] for s in stdRGB])/255
stdB = np.mean([s[2] for s in stdRGB])/255

print("test 평균",meanR, meanG, meanB)
print("test 표준편차",stdR, stdG, stdB)

# test 평균 0.41825619520929724 0.3931011906330291 0.386631764639131
# test 표준편차 0.19505524270747931 0.19005280951759498 0.18053225852732663
# Out:
# test 평균 0.41825619520929724 0.3931011906330291 0.386631764639131
# test 표준편차 0.19505524270747931 0.19005280951759498 0.18053225852732663

# %% [markdown]
# ☆ Custom_dataset : dataset 생성하는 class
# - \_\_init\_\_ : 생성자, 매개변수를 객체에 전달
# - \_\_len\_\_ : img_paths 변수의 길이 return
# - \_\_getitem\_\_ :
#     인스턴스 변수에 직접 접근하지 않고 객체 자체를 통해서 슬라이싱을 구현, idx를 받아서 return
#     img_paths 에서 idx 위치의 이미지를 transform하여 idx 번째의 label과 함께 출력
#     transform 시 test 이미지에서 Affine, Flip, Rotation 의 변형을 주었으며, metal_nut의 경우 Flip을 제외함
#
# ☆ Network :
# - timm모듈을 사용, 신경망 모델 정의
# - torch.nn.Module을 상속
# - \_\_init\_\_ : 모델에서 사용될 module(efficient b4)정의 및 초기화
# - forward() : 모델에서 실행되어야하는 계산을 정의 (output 정의), init에서 정의된것들을 연결하는 메소드
#
# ☆ score_function
# ☆ main : seed 정의

# %%
class Custom_dataset(Dataset):
    def __init__(self, img_paths, labels, classes, mode='train'):
        self.img_paths = img_paths
        self.labels = labels
        self.mode=mode
        self.classes=classes
    def __len__(self):
        return len(self.img_paths)
    def __getitem__(self, idx):
        img = self.img_paths[idx]
        if self.mode == 'train':
            if self.classes[idx]==7:
                # print(idx, '7')
                train_transform = transforms.Compose([
                        transforms.ToTensor(),
                        transforms.Normalize(mean = [0.433038, 0.403458, 0.394151],
                                            std = [0.181572, 0.174035, 0.163234]),
                        transforms.RandomAffine((-45, 45)),
                    
                        transforms.RandomRotation((0,80))       #  이미지를 랜덤으로 degrees 각도로 회전한다.
                        
                    ])
                img = train_transform(img)
            else :
                train_transform = transforms.Compose([
                        transforms.ToTensor(),
                        transforms.Normalize(mean = [0.433038, 0.403458, 0.394151],
                                            std = [0.181572, 0.174035, 0.163234]),
                        transforms.RandomAffine((-45, 45)),
                    
                        transforms.RandomVerticalFlip(p=0.5),   # - 이미지를 랜덤으로 수직으로 뒤집는다. p =0이면 뒤집지 않는다.
                        transforms.RandomHorizontalFlip(p=0.5), # - 이미지를 랜덤으로 수평으로 뒤집는다.
                        transforms.RandomRotation((0,80))       #  이미지를 랜덤으로 degrees 각도로 회전한다.
                        
                    ])
                img = train_transform(img)
        if self.mode == 'test':
          test_transform = transforms.Compose([
                transforms.ToTensor(),
                transforms.Normalize(mean = [0.418256, 0.393101, 0.386632],
                                     std = [0.195055, 0.190053, 0.185323]),
              
            ])
          img = test_transform(img)

        
        label = self.labels[idx]
        return img, label
    
class Network(nn.Module):
    def __init__(self,mode = 'train'):
        super(Network, self).__init__()
        self.mode = mode
        if self.mode == 'train':
          self.model = timm.create_model('efficientnet_b4', pretrained=True, num_classes=88, drop_path_rate = 0.2)
        if self.mode == 'test':
          self.model = timm.create_model('efficientnet_b4', pretrained=True, num_classes=88, drop_path_rate = 0)
        
    def forward(self, x):
        x = self.model(x)
        return x

# %%
def score_function(real, pred):
    score = f1_score(real, pred, average="macro")
    return score

# %%
def main(seed = 2022):
    os.environ['PYTHONHASHSEED'] = str(seed)
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.benchmark = True
    
main(2022)

# %%
train_y.groupby('label')['label'].count().ravel()
# Out:
# array([ 10,  11,  11, 209,   7,   6,   6,   7,   5, 224,   6,   5,   5,
#         12,  11, 219,  11,  12,  10,  10,   9, 280,   9,   9,  10,   6,
#          6,   6, 264,   6,   6,   9,   9, 391,   9,   9,  10,  10,   9,
#         10, 245,   9,  13,  11,  12, 220,  12,  13,   9,  11,  13,  10,
#        267,   5,  12, 320,  12,  12,  13,  12,  12,   9,   9, 230,   8,
#          9,   8,  15,  60,   5,   5,   5, 213,   5,   4,   6, 247,   5,
#          5,  11,  10,   8,   9,   8, 240,   9,   9,   8], dtype=int64)

# %%
856+3421
# Out:
# 4277

# %%
import gc
# pd.set_option('display.max_row', 500)

cv = StratifiedKFold(n_splits = 5, random_state = 2022,shuffle=True)
batch_size = 32
epochs = 70
pred_ensemble = []


for idx, (train_idx, val_idx) in enumerate(cv.split(train_imgs, np.array(train_labels))):
    print("----------fold_{} start!----------".format(idx))
    print(train_idx)
    print(len(train_imgs))
    print(len(train_imgs[train_idx]))
    print(len(train_imgs[val_idx]))
    label_train = train_y['label'].iloc[train_idx]
    label_valid = train_y['label'].iloc[val_idx]
    print('학습 레이블 데이터 분포 : \n', label_train.value_counts())
    print('검증 레이블 데이터 분포 : \n', label_valid.value_counts())
# Out:
# ----------fold_0 start!----------
# [   0    1    2 ... 4274 4275 4276]
# 4277
# 3421
# 856
# 학습 레이블 데이터 분포 :
#  hazelnut-good                 313
# screw-good                    256
# carpet-good                   224
# pill-good                     214
# grid-good                     211
# wood-good                     198
# leather-good                  196
# zipper-good                   192
# tile-good                     184
# cable-good                    179
# metal_nut-good                176
# capsule-good                  175
# transistor-good               170
# bottle-good                   167
# toothbrush-good                48
# toothbrush-defective           12
# metal_nut-bent                 11
# pill-crack                     11
# screw-scratch_neck             11
# screw-thread_side              10
# pill-color                     10
# screw-thread_top               10
# metal_nut-flip                 10
# screw-manipulated_front         9
# capsule-poke                    9
# bottle-contamination            9
# capsule-scratch                 9
# wood-scratch                    9
# pill-scratch                    9
# screw-scratch_head              9
# metal_nut-color                 9
# pill-contamination              9
# capsule-crack                   9
# metal_nut-scratch               9
# bottle-broken_large             8
# pill-combined                   8
# pill-faulty_imprint             8
# zipper-broken_teeth             8
# carpet-thread                   8
# leather-glue                    8
# hazelnut-crack                  8
# leather-cut                     8
# bottle-broken_small             8
# hazelnut-cut                    8
# capsule-squeeze                 8
# leather-color                   8
# capsule-faulty_imprint          8
# carpet-cut                      8
# zipper-rough                    8
# carpet-color                    8
# tile-gray_stroke                7
# zipper-split_teeth              7
# zipper-combined                 7
# hazelnut-print                  7
# tile-oil                        7
# zipper-fabric_border            7
# tile-crack                      7
# carpet-hole                     7
# zipper-squeezed_teeth           7
# leather-poke                    7
# hazelnut-hole                   7
# leather-fold                    7
# tile-glue_strip                 7
# carpet-metal_contamination      7
# tile-rough                      6
# zipper-fabric_interior          6
# cable-bent_wire                 6
# cable-cable_swap                5
# grid-glue                       5
# cable-cut_inner_insulation      5
# grid-broken                     5
# cable-combined                  5
# grid-thread                     5
# wood-combined                   5
# wood-liquid                     4
# cable-poke_insulation           4
# cable-missing_cable             4
# transistor-cut_lead             4
# cable-cut_outer_insulation      4
# grid-metal_contamination        4
# transistor-misplaced            4
# grid-bent                       4
# transistor-damaged_case         4
# cable-missing_wire              4
# transistor-bent_lead            4
# pill-pill_type                  4
# wood-hole                       4
# wood-color                      3
# Name: label, dtype: int64
# 검증 레이블 데이터 분포 :
#  hazelnut-good                 78
# screw-good                    64
# carpet-good                   56
# grid-good                     53
# pill-good                     53
# wood-good                     49
# leather-good                  49
# zipper-good                   48
# tile-good                     46
# cable-good                    45
# capsule-good                  44
# metal_nut-good                44
# transistor-good               43
# bottle-good                   42
# toothbrush-good               12
# metal_nut-scratch              3
# toothbrush-defective           3
# pill-scratch                   3
# screw-manipulated_front        3
# capsule-faulty_imprint         3
# capsule-scratch                3
# bottle-broken_small            3
# screw-scratch_head             3
# pill-color                     3
# capsule-crack                  3
# pill-crack                     2
# cable-cut_inner_insulation     2
# leather-fold                   2
# carpet-metal_contamination     2
# leather-poke                   2
# pill-contamination             2
# hazelnut-hole                  2
# metal_nut-flip                 2
# zipper-broken_teeth            2
# metal_nut-color                2
# screw-thread_top               2
# tile-crack                     2
# grid-metal_contamination       2
# carpet-hole                    2
# leather-color                  2
# tile-rough                     2
# screw-scratch_neck             2
# hazelnut-print                 2
# zipper-fabric_interior         2
# carpet-thread                  2
# capsule-squeeze                2
# capsule-poke                   2
# bottle-broken_large            2
# metal_nut-bent                 2
# pill-faulty_imprint            2
# leather-glue                   2
# grid-bent                      2
# zipper-split_teeth             2
# cable-missing_cable            2
# bottle-contamination           2
# tile-glue_strip                2
# wood-scratch                   2
# leather-cut                    2
# zipper-fabric_border           2
# tile-oil                       2
# carpet-color                   2
# screw-thread_side              2
# wood-liquid                    1
# cable-combined                 1
# pill-combined                  1
# cable-poke_insulation          1
# transistor-cut_lead            1
# carpet-cut                     1
# tile-gray_stroke               1
# cable-bent_wire                1
# wood-combined                  1
# transistor-misplaced           1
# hazelnut-crack                 1
# cable-cut_outer_insulation     1
# zipper-rough                   1
# zipper-combined                1
# grid-broken                    1
# pill-pill_type                 1
# grid-thread                    1
# wood-color                     1
# hazelnut-cut                   1
# transistor-damaged_case        1
# zipper-squeezed_teeth          1
# cable-cable_swap               1
# wood-hole                      1
# grid-glue                      1
# transistor-bent_lead           1
# cable-missing_wire             1
# Name: label, dtype: int64
# ----------fold_1 start!----------
# [   0    1    2 ... 4272 4273 4274]
# 4277
# 3421
# 856
# 학습 레이블 데이터 분포 :
#  hazelnut-good                 313
# screw-good                    256
# carpet-good                   224
# pill-good                     213
# grid-good                     211
# wood-good                     198
# leather-good                  196
# zipper-good                   192
# tile-good                     184
# cable-good                    179
# metal_nut-good                176
# capsule-good                  175
# transistor-good               170
# bottle-good                   167
# toothbrush-good                48
# toothbrush-defective           12
# metal_nut-bent                 11
# pill-crack                     10
# metal_nut-flip                 10
# screw-thread_side              10
# pill-scratch                   10
# screw-thread_top               10
# pill-color                     10
# screw-scratch_head             10
# metal_nut-scratch              10
# screw-scratch_neck             10
# bottle-broken_small             9
# capsule-scratch                 9
# bottle-contamination            9
# capsule-crack                   9
# capsule-poke                    9
# screw-manipulated_front         9
# metal_nut-color                 9
# capsule-faulty_imprint          9
# pill-faulty_imprint             8
# leather-glue                    8
# zipper-broken_teeth             8
# leather-poke                    8
# carpet-color                    8
# wood-scratch                    8
# tile-glue_strip                 8
# leather-color                   8
# carpet-thread                   8
# pill-contamination              8
# zipper-split_teeth              8
# leather-cut                     8
# bottle-broken_large             8
# capsule-squeeze                 8
# carpet-metal_contamination      7
# carpet-cut                      7
# hazelnut-print                  7
# pill-combined                   7
# carpet-hole                     7
# zipper-rough                    7
# zipper-combined                 7
# hazelnut-crack                  7
# tile-crack                      7
# tile-gray_stroke                7
# tile-oil                        7
# leather-fold                    7
# hazelnut-cut                    7
# hazelnut-hole                   7
# zipper-fabric_border            7
# zipper-squeezed_teeth           6
# cable-cut_inner_insulation      6
# zipper-fabric_interior          6
# cable-bent_wire                 6
# tile-rough                      6
# cable-cable_swap                5
# grid-metal_contamination        5
# grid-thread                     5
# wood-combined                   5
# cable-missing_cable             5
# cable-combined                  5
# grid-bent                       5
# grid-broken                     5
# transistor-misplaced            4
# cable-missing_wire              4
# pill-pill_type                  4
# grid-glue                       4
# transistor-bent_lead            4
# transistor-damaged_case         4
# cable-poke_insulation           4
# wood-hole                       4
# cable-cut_outer_insulation      4
# wood-liquid                     4
# transistor-cut_lead             4
# wood-color                      3
# Name: label, dtype: int64
# 검증 레이블 데이터 분포 :
#  hazelnut-good                 78
# screw-good                    64
# carpet-good                   56
# pill-good                     54
# grid-good                     53
# leather-good                  49
# wood-good                     49
# zipper-good                   48
# tile-good                     46
# cable-good                    45
# capsule-good                  44
# metal_nut-good                44
# transistor-good               43
# bottle-good                   42
# toothbrush-good               12
# pill-crack                     3
# screw-scratch_neck             3
# capsule-scratch                3
# screw-manipulated_front        3
# pill-color                     3
# wood-scratch                   3
# toothbrush-defective           3
# pill-contamination             3
# capsule-crack                  3
# hazelnut-cut                   2
# bottle-broken_small            2
# grid-glue                      2
# bottle-contamination           2
# leather-color                  2
# zipper-rough                   2
# capsule-faulty_imprint         2
# hazelnut-hole                  2
# metal_nut-flip                 2
# leather-fold                   2
# hazelnut-crack                 2
# capsule-squeeze                2
# capsule-poke                   2
# metal_nut-bent                 2
# carpet-color                   2
# leather-glue                   2
# tile-crack                     2
# carpet-thread                  2
# tile-oil                       2
# screw-thread_top               2
# tile-rough                     2
# carpet-cut                     2
# screw-thread_side              2
# zipper-fabric_border           2
# zipper-fabric_interior         2
# carpet-metal_contamination     2
# zipper-squeezed_teeth          2
# leather-cut                    2
# carpet-hole                    2
# pill-scratch                   2
# metal_nut-scratch              2
# zipper-broken_teeth            2
# screw-scratch_head             2
# bottle-broken_large            2
# pill-combined                  2
# metal_nut-color                2
# hazelnut-print                 2
# pill-faulty_imprint            2
# cable-cable_swap               1
# wood-color                     1
# tile-glue_strip                1
# pill-pill_type                 1
# transistor-misplaced           1
# cable-bent_wire                1
# wood-liquid                    1
# cable-missing_wire             1
# grid-broken                    1
# grid-thread                    1
# grid-bent                      1
# wood-combined                  1
# wood-hole                      1
# leather-poke                   1
# grid-metal_contamination       1
# transistor-damaged_case        1
# cable-combined                 1
# tile-gray_stroke               1
# zipper-split_teeth             1
# zipper-combined                1
# cable-missing_cable            1
# cable-cut_inner_insulation     1
# transistor-cut_lead            1
# cable-poke_insulation          1
# cable-cut_outer_insulation     1
# transistor-bent_lead           1
# Name: label, dtype: int64
# ----------fold_2 start!----------
# [   1    3    4 ... 4274 4275 4276]
# 4277
# 3422
# 855
# 학습 레이블 데이터 분포 :
#  hazelnut-good                 313
# screw-good                    256
# carpet-good                   224
# pill-good                     213
# grid-good                     212
# wood-good                     197
# leather-good                  196
# zipper-good                   192
# tile-good                     184
# cable-good                    179
# capsule-good                  176
# metal_nut-good                176
# transistor-good               170
# bottle-good                   167
# toothbrush-good                48
# toothbrush-defective           12
# metal_nut-flip                 10
# screw-scratch_head             10
# pill-color                     10
# capsule-scratch                10
# metal_nut-scratch              10
# metal_nut-bent                 10
# screw-thread_top               10
# screw-scratch_neck             10
# capsule-crack                  10
# screw-thread_side              10
# screw-manipulated_front        10
# pill-scratch                   10
# pill-crack                     10
# bottle-broken_small             9
# capsule-faulty_imprint          9
# pill-contamination              9
# wood-scratch                    9
# metal_nut-color                 9
# carpet-color                    8
# zipper-broken_teeth             8
# leather-glue                    8
# hazelnut-hole                   8
# pill-faulty_imprint             8
# carpet-thread                   8
# leather-cut                     8
# leather-color                   8
# bottle-broken_large             8
# capsule-poke                    8
# bottle-contamination            8
# capsule-squeeze                 8
# leather-fold                    8
# tile-rough                      7
# carpet-hole                     7
# carpet-cut                      7
# zipper-rough                    7
# zipper-split_teeth              7
# hazelnut-print                  7
# carpet-metal_contamination      7
# zipper-fabric_border            7
# tile-oil                        7
# tile-glue_strip                 7
# hazelnut-crack                  7
# leather-poke                    7
# tile-crack                      7
# hazelnut-cut                    7
# pill-combined                   7
# cable-cut_inner_insulation      6
# zipper-squeezed_teeth           6
# cable-bent_wire                 6
# zipper-combined                 6
# tile-gray_stroke                6
# zipper-fabric_interior          6
# cable-combined                  5
# grid-metal_contamination        5
# wood-combined                   5
# grid-glue                       5
# cable-cable_swap                5
# grid-bent                       5
# cable-missing_cable             5
# grid-thread                     5
# transistor-misplaced            4
# cable-cut_outer_insulation      4
# cable-missing_wire              4
# transistor-damaged_case         4
# cable-poke_insulation           4
# transistor-cut_lead             4
# pill-pill_type                  4
# wood-hole                       4
# grid-broken                     4
# wood-liquid                     4
# transistor-bent_lead            4
# wood-color                      3
# Name: label, dtype: int64
# 검증 레이블 데이터 분포 :
#  hazelnut-good                 78
# screw-good                    64
# carpet-good                   56
# pill-good                     54
# grid-good                     52
# wood-good                     50
# leather-good                  49
# zipper-good                   48
# tile-good                     46
# cable-good                    45
# metal_nut-good                44
# transistor-good               43
# capsule-good                  43
# bottle-good                   42
# toothbrush-good               12
# metal_nut-bent                 3
# capsule-poke                   3
# pill-color                     3
# toothbrush-defective           3
# screw-scratch_neck             3
# bottle-contamination           3
# pill-crack                     3
# carpet-cut                     2
# capsule-scratch                2
# bottle-broken_large            2
# screw-manipulated_front        2
# carpet-color                   2
# tile-glue_strip                2
# wood-scratch                   2
# bottle-broken_small            2
# tile-gray_stroke               2
# pill-combined                  2
# carpet-metal_contamination     2
# pill-scratch                   2
# zipper-squeezed_teeth          2
# screw-thread_top               2
# capsule-faulty_imprint         2
# leather-color                  2
# leather-glue                   2
# screw-scratch_head             2
# metal_nut-flip                 2
# zipper-fabric_border           2
# capsule-crack                  2
# tile-crack                     2
# pill-faulty_imprint            2
# carpet-thread                  2
# pill-contamination             2
# hazelnut-crack                 2
# zipper-split_teeth             2
# grid-broken                    2
# metal_nut-scratch              2
# capsule-squeeze                2
# leather-poke                   2
# zipper-fabric_interior         2
# hazelnut-print                 2
# carpet-hole                    2
# zipper-rough                   2
# zipper-combined                2
# screw-thread_side              2
# metal_nut-color                2
# tile-oil                       2
# zipper-broken_teeth            2
# hazelnut-cut                   2
# leather-cut                    2
# wood-combined                  1
# cable-missing_wire             1
# wood-hole                      1
# wood-color                     1
# grid-metal_contamination       1
# pill-pill_type                 1
# cable-bent_wire                1
# hazelnut-hole                  1
# transistor-cut_lead            1
# leather-fold                   1
# cable-cable_swap               1
# transistor-bent_lead           1
# cable-missing_cable            1
# tile-rough                     1
# cable-cut_outer_insulation     1
# cable-cut_inner_insulation     1
# grid-bent                      1
# wood-liquid                    1
# cable-poke_insulation          1
# transistor-damaged_case        1
# grid-glue                      1
# transistor-misplaced           1
# grid-thread                    1
# cable-combined                 1
# Name: label, dtype: int64
# ----------fold_3 start!----------
# [   0    2    3 ... 4274 4275 4276]
# 4277
# 3422
# 855
# 학습 레이블 데이터 분포 :
#  hazelnut-good                 313
# screw-good                    256
# carpet-good                   224
# pill-good                     214
# grid-good                     211
# wood-good                     197
# leather-good                  196
# zipper-good                   192
# tile-good                     184
# cable-good                    179
# metal_nut-good                176
# capsule-good                  175
# transistor-good               171
# bottle-good                   168
# toothbrush-good                48
# toothbrush-defective           12
# pill-color                     11
# screw-scratch_head             10
# capsule-crack                  10
# metal_nut-bent                 10
# screw-manipulated_front        10
# pill-crack                     10
# pill-scratch                   10
# metal_nut-scratch              10
# screw-scratch_neck             10
# capsule-scratch                10
# pill-contamination              9
# metal_nut-color                 9
# wood-scratch                    9
# capsule-faulty_imprint          9
# bottle-broken_small             9
# metal_nut-flip                  9
# bottle-contamination            9
# capsule-poke                    9
# screw-thread_side               9
# screw-thread_top                9
# leather-cut                     8
# carpet-thread                   8
# leather-glue                    8
# carpet-color                    8
# leather-color                   8
# pill-faulty_imprint             8
# capsule-squeeze                 8
# bottle-broken_large             8
# zipper-broken_teeth             8
# carpet-hole                     7
# tile-oil                        7
# leather-poke                    7
# zipper-fabric_border            7
# tile-rough                      7
# hazelnut-hole                   7
# hazelnut-crack                  7
# carpet-metal_contamination      7
# pill-combined                   7
# carpet-cut                      7
# tile-crack                      7
# zipper-split_teeth              7
# leather-fold                    7
# hazelnut-cut                    7
# zipper-rough                    7
# tile-glue_strip                 7
# zipper-fabric_interior          7
# hazelnut-print                  7
# zipper-squeezed_teeth           6
# zipper-combined                 6
# tile-gray_stroke                6
# cable-cut_inner_insulation      6
# grid-bent                       5
# cable-combined                  5
# cable-cable_swap                5
# cable-missing_cable             5
# grid-glue                       5
# wood-combined                   5
# cable-bent_wire                 5
# grid-metal_contamination        5
# grid-thread                     5
# grid-broken                     5
# cable-missing_wire              4
# cable-cut_outer_insulation      4
# transistor-bent_lead            4
# cable-poke_insulation           4
# transistor-cut_lead             4
# transistor-misplaced            4
# wood-hole                       4
# pill-pill_type                  4
# transistor-damaged_case         4
# wood-liquid                     4
# wood-color                      3
# Name: label, dtype: int64
# 검증 레이블 데이터 분포 :
#  hazelnut-good                 78
# screw-good                    64
# carpet-good                   56
# pill-good                     53
# grid-good                     53
# wood-good                     50
# leather-good                  49
# zipper-good                   48
# tile-good                     46
# cable-good                    45
# metal_nut-good                44
# capsule-good                  44
# transistor-good               42
# bottle-good                   41
# toothbrush-good               12
# metal_nut-flip                 3
# toothbrush-defective           3
# screw-thread_top               3
# metal_nut-bent                 3
# screw-thread_side              3
# screw-scratch_neck             3
# pill-crack                     3
# hazelnut-cut                   2
# zipper-broken_teeth            2
# capsule-poke                   2
# leather-color                  2
# leather-glue                   2
# leather-cut                    2
# carpet-metal_contamination     2
# tile-glue_strip                2
# hazelnut-crack                 2
# zipper-rough                   2
# pill-color                     2
# wood-scratch                   2
# tile-crack                     2
# metal_nut-scratch              2
# capsule-faulty_imprint         2
# tile-gray_stroke               2
# carpet-cut                     2
# zipper-fabric_border           2
# tile-oil                       2
# capsule-crack                  2
# carpet-color                   2
# screw-manipulated_front        2
# zipper-split_teeth             2
# cable-bent_wire                2
# zipper-combined                2
# pill-combined                  2
# screw-scratch_head             2
# metal_nut-color                2
# leather-fold                   2
# pill-faulty_imprint            2
# zipper-squeezed_teeth          2
# capsule-scratch                2
# carpet-hole                    2
# hazelnut-hole                  2
# bottle-broken_large            2
# pill-scratch                   2
# leather-poke                   2
# bottle-contamination           2
# pill-contamination             2
# bottle-broken_small            2
# hazelnut-print                 2
# carpet-thread                  2
# capsule-squeeze                2
# pill-pill_type                 1
# grid-thread                    1
# grid-glue                      1
# grid-broken                    1
# wood-combined                  1
# wood-hole                      1
# transistor-misplaced           1
# zipper-fabric_interior         1
# cable-cut_outer_insulation     1
# transistor-cut_lead            1
# grid-bent                      1
# transistor-damaged_case        1
# transistor-bent_lead           1
# cable-combined                 1
# wood-liquid                    1
# tile-rough                     1
# cable-poke_insulation          1
# cable-missing_cable            1
# cable-cut_inner_insulation     1
# cable-cable_swap               1
# cable-missing_wire             1
# wood-color                     1
# grid-metal_contamination       1
# Name: label, dtype: int64
# ----------fold_4 start!----------
# [   0    1    2 ... 4273 4275 4276]
# 4277
# 3422
# 855
# 학습 레이블 데이터 분포 :
#  hazelnut-good                 312
# screw-good                    256
# carpet-good                   224
# pill-good                     214
# grid-good                     211
# wood-good                     198
# leather-good                  196
# zipper-good                   192
# tile-good                     184
# cable-good                    180
# metal_nut-good                176
# capsule-good                  175
# transistor-good               171
# bottle-good                   167
# toothbrush-good                48
# toothbrush-defective           12
# pill-crack                     11
# pill-color                     11
# screw-scratch_neck             11
# screw-manipulated_front        10
# capsule-scratch                10
# metal_nut-bent                 10
# capsule-crack                  10
# wood-scratch                    9
# capsule-faulty_imprint          9
# screw-scratch_head              9
# bottle-broken_small             9
# pill-contamination              9
# bottle-contamination            9
# screw-thread_top                9
# pill-scratch                    9
# metal_nut-flip                  9
# screw-thread_side               9
# metal_nut-scratch               9
# capsule-poke                    9
# carpet-color                    8
# carpet-thread                   8
# hazelnut-print                  8
# leather-glue                    8
# pill-faulty_imprint             8
# bottle-broken_large             8
# tile-oil                        8
# tile-crack                      8
# carpet-metal_contamination      8
# leather-cut                     8
# carpet-hole                     8
# leather-color                   8
# zipper-fabric_border            8
# zipper-broken_teeth             8
# capsule-squeeze                 8
# metal_nut-color                 8
# hazelnut-crack                  7
# pill-combined                   7
# zipper-split_teeth              7
# zipper-squeezed_teeth           7
# hazelnut-cut                    7
# zipper-rough                    7
# leather-poke                    7
# zipper-fabric_interior          7
# carpet-cut                      7
# leather-fold                    7
# tile-glue_strip                 7
# hazelnut-hole                   7
# tile-gray_stroke                6
# zipper-combined                 6
# tile-rough                      6
# grid-metal_contamination        5
# cable-cut_inner_insulation      5
# cable-missing_cable             5
# grid-bent                       5
# grid-glue                       5
# cable-bent_wire                 5
# grid-broken                     5
# cable-combined                  4
# wood-hole                       4
# transistor-cut_lead             4
# cable-poke_insulation           4
# pill-pill_type                  4
# wood-combined                   4
# cable-cable_swap                4
# transistor-bent_lead            4
# transistor-misplaced            4
# cable-missing_wire              4
# wood-color                      4
# cable-cut_outer_insulation      4
# grid-thread                     4
# transistor-damaged_case         4
# wood-liquid                     4
# Name: label, dtype: int64
# 검증 레이블 데이터 분포 :
#  hazelnut-good                 79
# screw-good                    64
# carpet-good                   56
# grid-good                     53
# pill-good                     53
# wood-good                     49
# leather-good                  49
# zipper-good                   48
# tile-good                     46
# metal_nut-good                44
# capsule-good                  44
# cable-good                    44
# transistor-good               42
# bottle-good                   42
# toothbrush-good               12
# screw-thread_top               3
# toothbrush-defective           3
# metal_nut-bent                 3
# screw-scratch_head             3
# metal_nut-color                3
# pill-scratch                   3
# metal_nut-scratch              3
# metal_nut-flip                 3
# screw-thread_side              3
# grid-thread                    2
# leather-glue                   2
# cable-bent_wire                2
# capsule-squeeze                2
# capsule-faulty_imprint         2
# cable-cable_swap               2
# pill-combined                  2
# leather-color                  2
# bottle-broken_small            2
# screw-scratch_neck             2
# carpet-cut                     2
# leather-fold                   2
# hazelnut-crack                 2
# tile-rough                     2
# capsule-scratch                2
# cable-combined                 2
# leather-poke                   2
# wood-combined                  2
# zipper-combined                2
# bottle-contamination           2
# leather-cut                    2
# carpet-color                   2
# zipper-split_teeth             2
# bottle-broken_large            2
# zipper-rough                   2
# carpet-thread                  2
# hazelnut-hole                  2
# pill-crack                     2
# capsule-crack                  2
# pill-color                     2
# tile-gray_stroke               2
# screw-manipulated_front        2
# hazelnut-cut                   2
# capsule-poke                   2
# pill-contamination             2
# zipper-broken_teeth            2
# cable-cut_inner_insulation     2
# wood-scratch                   2
# pill-faulty_imprint            2
# tile-glue_strip                2
# transistor-bent_lead           1
# transistor-cut_lead            1
# grid-bent                      1
# cable-cut_outer_insulation     1
# hazelnut-print                 1
# zipper-fabric_border           1
# wood-liquid                    1
# cable-missing_cable            1
# carpet-metal_contamination     1
# zipper-fabric_interior         1
# grid-glue                      1
# cable-missing_wire             1
# wood-hole                      1
# cable-poke_insulation          1
# grid-broken                    1
# tile-oil                       1
# pill-pill_type                 1
# carpet-hole                    1
# transistor-misplaced           1
# grid-metal_contamination       1
# transistor-damaged_case        1
# zipper-squeezed_teeth          1
# tile-crack                     1
# Name: label, dtype: int64

# %% [markdown]
# ## StratifiedKFold

# %% [markdown]
# gc : Garbage Collector
# gc.collect() : 메모리 관리 작업을 수행, 메모리 사용을 마쳤을 때 메모리를 비움
#
# torch.cuda.empty_cache() : 사용되지 않는 GPU상 cache를 정리
#
# torch.cuda.amp.autocast() : autocasting을 위한 모듈 제공
# torch.cuda.amp.GradScaler() :
#     backward 시 underflow방지를 위해 float32범위로 스케일
#     옵티마이저가 파라미터를 업데이트하기전에 원래 스케일대로 복구
#
# optimizer.zero_grad() : 이상적인 학습을 위한 backward()를 호출할 때 하는 초기설정
#
# eval() : train time과 eval time에서 수행하는 다른 작업을 수행할 수 있도록 switching 하는 함수
#     torch.no_grad()와 함께 쓰인다.
#     evaluation(평가) 시 쓰지 말아야 할 layer들을 알아서 off 시키도록 하는 함수인 셈이다.
#
# early_stopping : early_stoppying

# %%
import gc

cv = StratifiedKFold(n_splits = 5, random_state = 2022,shuffle=True)
batch_size = 32
epochs = 70
pred_ensemble = []


for idx, (train_idx, val_idx) in enumerate(cv.split(train_imgs, np.array(train_labels))):
  print("----------fold_{} start!----------".format(idx))
  t_imgs, val_imgs = train_imgs[train_idx],  train_imgs[val_idx]
  t_labels, val_labels = np.array(train_labels)[train_idx], np.array(train_labels)[val_idx]

  # Train
  train_dataset = Custom_dataset(np.array(train_imgs), np.array(train_labels), np.array(train_classes), mode='train')
  train_loader = DataLoader(train_dataset, shuffle=True, batch_size=batch_size)

  # Val
  val_dataset = Custom_dataset(np.array(val_imgs), np.array(val_labels), np.array([]), mode='test')
  val_loader = DataLoader(val_dataset, shuffle=True, batch_size=batch_size)


  gc.collect()
  torch.cuda.empty_cache()
  best=0

  model = Network().to(device)

#   optimizer = torch.optim.AdamW(model.parameters(), lr=2e-4, weight_decay = 2e-2)
  optimizer = torch.optim.Adadelta(model.parameters())
  criterion = nn.CrossEntropyLoss()
  scaler = torch.cuda.amp.GradScaler()  

  best_f1 = 0
  early_stopping = 0
  for epoch in range(epochs):
    start=time.time()
    train_loss = 0
    train_pred=[]
    train_y=[]
    model.train()
    for batch in (train_loader):
        optimizer.zero_grad()
        x = torch.tensor(batch[0], dtype=torch.float32, device=device)
        y = torch.tensor(batch[1], dtype=torch.long, device=device)
        with torch.cuda.amp.autocast():
            pred = model(x)
        loss = criterion(pred, y)


        scaler.scale(loss).backward()
        scaler.step(optimizer)
        scaler.update()
        
        train_loss += loss.item()/len(train_loader)
        train_pred += pred.argmax(1).detach().cpu().numpy().tolist()
        train_y += y.detach().cpu().numpy().tolist()
    train_f1 = score_function(train_y, train_pred)
    state_dict= model.state_dict()
    model.eval()
    with torch.no_grad():
      val_loss = 0 
      val_pred = []
      val_y = []
      

      for batch in (val_loader):
        x_val = torch.tensor(batch[0], dtype = torch.float32, device = device)
        y_val = torch.tensor(batch[1], dtype=torch.long, device=device)
        with torch.cuda.amp.autocast():
            pred_val = model(x_val)
        loss_val = criterion(pred_val, y_val)

        val_loss += loss_val.item()/len(val_loader)
        val_pred += pred_val.argmax(1).detach().cpu().numpy().tolist()
        val_y += y_val.detach().cpu().numpy().tolist()
      val_f1 = score_function(val_y, val_pred)

      if val_f1 > best_f1:
        best_epoch = epoch
        best_loss = val_loss
        best_f1 = val_f1
        early_stopping = 0

        torch.save({'epoch':epoch,
                    'state_dict':state_dict,
                    'optimizer': optimizer.state_dict(),
                    'scaler': scaler.state_dict(),
             }, path +'0513_best_model_{}.pth'.format(idx))
        print('-----------------SAVE:{} epoch----------------'.format(best_epoch+1))
      else:
          early_stopping += 1

            # Early Stopping
      if early_stopping == 20:
        TIME = time.time() - start
        print(f'epoch : {epoch+1}/{epochs}    time : {TIME:.0f}s/{TIME*(epochs-epoch-1):.0f}s')
        print(f'TRAIN    loss : {train_loss:.5f}    f1 : {train_f1:.5f}')
        print(f'Val    loss : {val_loss:.5f}    f1 : {val_f1:.5f}')
        break

    TIME = time.time() - start
    print(f'epoch : {epoch+1}/{epochs}    time : {TIME:.0f}s/{TIME*(epochs-epoch-1):.0f}s')
    print(f'TRAIN    loss : {train_loss:.5f}    f1 : {train_f1:.5f}')
    print(f'Val    loss : {val_loss:.5f}    f1 : {val_f1:.5f}')
# Out:
# ----------fold_0 start!----------
# -----------------SAVE:1 epoch----------------
# epoch : 1/70    time : 194s/13377s
# TRAIN    loss : 1.06271    f1 : 0.19991
# Val    loss : 0.53866    f1 : 0.33082
# -----------------SAVE:2 epoch----------------
# epoch : 2/70    time : 180s/12210s
# TRAIN    loss : 0.50609    f1 : 0.37492
# Val    loss : 0.39828    f1 : 0.44426
# -----------------SAVE:3 epoch----------------
# epoch : 3/70    time : 167s/11203s
# TRAIN    loss : 0.37039    f1 : 0.56183
# Val    loss : 0.28328    f1 : 0.58649
# -----------------SAVE:4 epoch----------------
# epoch : 4/70    time : 168s/11056s
# TRAIN    loss : 0.30820    f1 : 0.59011
# Val    loss : 0.21666    f1 : 0.61284
# -----------------SAVE:5 epoch----------------
# epoch : 5/70    time : 167s/10849s
# TRAIN    loss : 0.23587    f1 : 0.69419
# Val    loss : 0.22197    f1 : 0.73400
# -----------------SAVE:6 epoch----------------
# epoch : 6/70    time : 167s/10697s
# TRAIN    loss : 0.19172    f1 : 0.74630
# Val    loss : 0.11249    f1 : 0.79707
# -----------------SAVE:7 epoch----------------
# epoch : 7/70    time : 167s/10525s
# TRAIN    loss : 0.14890    f1 : 0.78450
# Val    loss : 0.08893    f1 : 0.85555
# epoch : 8/70    time : 166s/10289s
# TRAIN    loss : 0.13520    f1 : 0.81985
# Val    loss : 0.10474    f1 : 0.83327
# -----------------SAVE:9 epoch----------------
# epoch : 9/70    time : 176s/10708s
# TRAIN    loss : 0.11765    f1 : 0.85053
# Val    loss : 0.08126    f1 : 0.86128
# -----------------SAVE:10 epoch----------------
# epoch : 10/70    time : 175s/10525s
# TRAIN    loss : 0.10243    f1 : 0.88477
# Val    loss : 0.05876    f1 : 0.89792
# -----------------SAVE:11 epoch----------------
# epoch : 11/70    time : 176s/10364s
# TRAIN    loss : 0.09110    f1 : 0.87531
# Val    loss : 0.03367    f1 : 0.92837
# epoch : 12/70    time : 168s/9735s
# TRAIN    loss : 0.08543    f1 : 0.88553
# Val    loss : 0.04637    f1 : 0.92528
# -----------------SAVE:13 epoch----------------
# epoch : 13/70    time : 168s/9578s
# TRAIN    loss : 0.08123    f1 : 0.90775
# Val    loss : 0.03449    f1 : 0.95231
# epoch : 14/70    time : 167s/9359s
# TRAIN    loss : 0.06858    f1 : 0.91495
# Val    loss : 0.04648    f1 : 0.94537
# epoch : 15/70    time : 167s/9194s
# TRAIN    loss : 0.05841    f1 : 0.92393
# Val    loss : 0.05095    f1 : 0.94684
# epoch : 16/70    time : 166s/8983s
# TRAIN    loss : 0.05169    f1 : 0.93264
# Val    loss : 0.03793    f1 : 0.91829
# -----------------SAVE:17 epoch----------------
# epoch : 17/70    time : 169s/8935s
# TRAIN    loss : 0.05958    f1 : 0.93157
# Val    loss : 0.02765    f1 : 0.97355
# -----------------SAVE:18 epoch----------------
# epoch : 18/70    time : 168s/8750s
# TRAIN    loss : 0.04864    f1 : 0.94365
# Val    loss : 0.01973    f1 : 0.98012
# epoch : 19/70    time : 167s/8495s
# TRAIN    loss : 0.03887    f1 : 0.94481
# Val    loss : 0.01881    f1 : 0.96308
# epoch : 20/70    time : 167s/8334s
# TRAIN    loss : 0.03422    f1 : 0.95548
# Val    loss : 0.01359    f1 : 0.97089
# -----------------SAVE:21 epoch----------------
# epoch : 21/70    time : 167s/8183s
# TRAIN    loss : 0.03376    f1 : 0.95880
# Val    loss : 0.02180    f1 : 0.98508
# epoch : 22/70    time : 167s/8037s
# TRAIN    loss : 0.04375    f1 : 0.94875
# Val    loss : 0.01384    f1 : 0.98217
# epoch : 23/70    time : 168s/7882s
# TRAIN    loss : 0.03908    f1 : 0.95497
# Val    loss : 0.01578    f1 : 0.97908
# epoch : 24/70    time : 168s/7724s
# TRAIN    loss : 0.03456    f1 : 0.96220
# Val    loss : 0.01429    f1 : 0.97532
# epoch : 25/70    time : 166s/7472s
# TRAIN    loss : 0.03544    f1 : 0.95603
# Val    loss : 0.02297    f1 : 0.95051
# -----------------SAVE:26 epoch----------------
# epoch : 26/70    time : 167s/7344s
# TRAIN    loss : 0.02508    f1 : 0.97373
# Val    loss : 0.00565    f1 : 0.99223
# epoch : 27/70    time : 167s/7198s
# TRAIN    loss : 0.02349    f1 : 0.97278
# Val    loss : 0.01872    f1 : 0.96949
# epoch : 28/70    time : 166s/6974s
# TRAIN    loss : 0.02596    f1 : 0.96807
# Val    loss : 0.02030    f1 : 0.98058
# epoch : 29/70    time : 166s/6799s
# TRAIN    loss : 0.01651    f1 : 0.98292
# Val    loss : 0.00408    f1 : 0.98247
# epoch : 30/70    time : 166s/6654s
# TRAIN    loss : 0.01708    f1 : 0.98354
# Val    loss : 0.03343    f1 : 0.97245
# epoch : 31/70    time : 168s/6534s
# TRAIN    loss : 0.02052    f1 : 0.98113
# Val    loss : 0.01512    f1 : 0.99156
# -----------------SAVE:32 epoch----------------
# epoch : 32/70    time : 168s/6369s
# TRAIN    loss : 0.02124    f1 : 0.97186
# Val    loss : 0.00614    f1 : 0.99305
# epoch : 33/70    time : 167s/6163s
# TRAIN    loss : 0.01819    f1 : 0.98002
# Val    loss : 0.01749    f1 : 0.98156
# -----------------SAVE:34 epoch----------------
# epoch : 34/70    time : 168s/6033s
# TRAIN    loss : 0.02314    f1 : 0.97870
# Val    loss : 0.00410    f1 : 1.00000
# epoch : 35/70    time : 167s/5842s
# TRAIN    loss : 0.01834    f1 : 0.97725
# Val    loss : 0.00207    f1 : 1.00000
# epoch : 36/70    time : 166s/5656s
# TRAIN    loss : 0.01431    f1 : 0.97413
# Val    loss : 0.00762    f1 : 0.99242
# epoch : 37/70    time : 166s/5466s
# TRAIN    loss : 0.01239    f1 : 0.99270
# Val    loss : 0.04301    f1 : 0.96216
# epoch : 38/70    time : 167s/5341s
# TRAIN    loss : 0.01685    f1 : 0.98662
# Val    loss : 0.00837    f1 : 0.99067
# epoch : 39/70    time : 167s/5192s
# TRAIN    loss : 0.02011    f1 : 0.98360
# Val    loss : 0.01395    f1 : 0.97693
# epoch : 40/70    time : 167s/5010s
# TRAIN    loss : 0.01869    f1 : 0.97973
# Val    loss : 0.01493    f1 : 0.97745
# epoch : 41/70    time : 166s/4806s
# TRAIN    loss : 0.01163    f1 : 0.98648
# Val    loss : 0.01042    f1 : 0.99432
# epoch : 42/70    time : 166s/4647s
# TRAIN    loss : 0.01483    f1 : 0.98012
# Val    loss : 0.00300    f1 : 1.00000
# epoch : 43/70    time : 166s/4477s
# TRAIN    loss : 0.00897    f1 : 0.98863
# Val    loss : 0.00501    f1 : 0.99585
# epoch : 44/70    time : 166s/4313s
# TRAIN    loss : 0.01096    f1 : 0.98867
# Val    loss : 0.00280    f1 : 0.99825
# epoch : 45/70    time : 166s/4138s
# TRAIN    loss : 0.01115    f1 : 0.98792
# Val    loss : 0.00966    f1 : 0.96856
# epoch : 46/70    time : 166s/3978s
# TRAIN    loss : 0.01346    f1 : 0.98583
# Val    loss : 0.00490    f1 : 0.98459
# epoch : 47/70    time : 166s/3809s
# TRAIN    loss : 0.01120    f1 : 0.97929
# Val    loss : 0.00409    f1 : 0.98851
# epoch : 48/70    time : 168s/3692s
# TRAIN    loss : 0.00884    f1 : 0.98888
# Val    loss : 0.00107    f1 : 1.00000
# epoch : 49/70    time : 173s/3623s
# TRAIN    loss : 0.00693    f1 : 0.99372
# Val    loss : 0.00355    f1 : 0.99459
# epoch : 50/70    time : 174s/3483s
# TRAIN    loss : 0.01433    f1 : 0.98764
# Val    loss : 0.01096    f1 : 0.99242
# epoch : 51/70    time : 172s/3261s
# TRAIN    loss : 0.00762    f1 : 0.99478
# Val    loss : 0.00892    f1 : 0.98831

# %%
pred_ensemble = []
batch_size = 32
# Test
test_dataset = Custom_dataset(np.array(test_imgs), np.array(["tmp"]*len(test_imgs)), np.array(train_classes), mode='test')
test_loader = DataLoader(test_dataset, shuffle=False, batch_size=batch_size)

for i in range(5):
  model_test = Network(mode = 'test').to(device)
  model_test.load_state_dict(torch.load((path+'0513_best_model_{}.pth'.format(i)))['state_dict'])
  model_test.eval()
  pred_prob = []
  with torch.no_grad():
      for batch in (test_loader):
          x = torch.tensor(batch[0], dtype = torch.float32, device = device)
          with torch.cuda.amp.autocast():
              pred = model_test(x)
              pred_prob.extend(pred.detach().cpu().numpy())
      pred_ensemble.append(pred_prob)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Input In [10], in <cell line: 7>()
#       5 test_loader = DataLoader(test_dataset, shuffle=False, batch_size=batch_size)
#       7 for i in range(3):
# ----> 8   model_test = Network(mode = 'test').to(device)
#       9   model_test.load_state_dict(torch.load((path+'0513_best_model_{}.pth'.format(i)))['state_dict'])
#      10   model_test.eval()
#
# File ~\anaconda3\envs\machine_TF2\lib\site-packages\torch\nn\modules\module.py:907, in Module.to(self, *args, **kwargs)
#     903         return t.to(device, dtype if t.is_floating_point() or t.is_complex() else None,
#     904                     non_blocking, memory_format=convert_to_format)
#     905     return t.to(device, dtype if t.is_floating_point() or t.is_complex() else None, non_blocking)
# --> 907 return self._apply(convert)
#
# File ~\anaconda3\envs\machine_TF2\lib\site-packages\torch\nn\modules\module.py:578, in Module._apply(self, fn)
#     576 def _apply(self, fn):
#     577     for module in self.children():
# --> 578         module._apply(fn)
#     580     def compute_should_use_set_data(tensor, tensor_applied):
#     581         if torch._has_compatible_shallow_copy_type(tensor, tensor_applied):
#     582             # If the new tensor has compatible tensor type as the existing tensor,
#     583             # the current behavior is to change the tensor in-place using `.data =`,
#    (...)
#     588             # global flag to let the user control whether they want the future
#     589             # behavior of overwriting the existing tensor or not.
#
# File ~\anaconda3\envs\machine_TF2\lib\site-packages\torch\nn\modules\module.py:578, in Module._apply(self, fn)
#     576 def _apply(self, fn):
#     577     for module in self.children():
# --> 578         module._apply(fn)
#     580     def compute_should_use_set_data(tensor, tensor_applied):
#     581         if torch._has_compatible_shallow_copy_type(tensor, tensor_applied):
#     582             # If the new tensor has compatible tensor type as the existing tensor,
#     583             # the current behavior is to change the tensor in-place using `.data =`,
#    (...)
#     588             # global flag to let the user control whether they want the future
#     589             # behavior of overwriting the existing tensor or not.
#
# File ~\anaconda3\envs\machine_TF2\lib\site-packages\torch\nn\modules\module.py:601, in Module._apply(self, fn)
#     597 # Tensors stored in modules are graph leaves, and we don't want to
#     598 # track autograd history of `param_applied`, so we have to use
#     599 # `with torch.no_grad():`
#     600 with torch.no_grad():
# --> 601     param_applied = fn(param)
#     602 should_use_set_data = compute_should_use_set_data(param, param_applied)
#     603 if should_use_set_data:
#
# File ~\anaconda3\envs\machine_TF2\lib\site-packages\torch\nn\modules\module.py:905, in Module.to.<locals>.convert(t)
#     902 if convert_to_format is not None and t.dim() in (4, 5):
#     903     return t.to(device, dtype if t.is_floating_point() or t.is_complex() else None,
#     904                 non_blocking, memory_format=convert_to_format)
# --> 905 return t.to(device, dtype if t.is_floating_point() or t.is_complex() else None, non_blocking)
#
# File ~\anaconda3\envs\machine_TF2\lib\site-packages\torch\cuda\__init__.py:210, in _lazy_init()
#     206     raise RuntimeError(
#     207         "Cannot re-initialize CUDA in forked subprocess. To use CUDA with "
#     208         "multiprocessing, you must use the 'spawn' start method")
#     209 if not hasattr(torch._C, '_cuda_getDeviceCount'):
# --> 210     raise AssertionError("Torch not compiled with CUDA enabled")
#     211 if _cudart is None:
#     212     raise AssertionError(
#     213         "libcudart functions unavailable. It looks like you have a broken build?")
#
# AssertionError: Torch not compiled with CUDA enabled

# %%
len(pred_ensemble)
# Out:
# 5

# %%
pred = (np.array(pred_ensemble[0])+ np.array(pred_ensemble[1])+ np.array(pred_ensemble[3]) + np.array(pred_ensemble[4]) )/4
f_pred = np.array(pred).argmax(1).tolist()

# %%
label_decoder = {val:key for key, val in label_unique.items()}

f_result = [label_decoder[result] for result in f_pred]

# %%
submission = pd.read_csv(path + "data/sample_submission.csv")

submission["label"] = f_result

submission
# Out:
#       index             label
# 0         0   tile-glue_strip
# 1         1         grid-good
# 2         2   transistor-good
# 3         3  tile-gray_stroke
# 4         4         tile-good
# ...     ...               ...
# 2149   2149  tile-gray_stroke
# 2150   2150        screw-good
# 2151   2151         grid-good
# 2152   2152        cable-good
# 2153   2153       zipper-good
#
# [2154 rows x 2 columns]

# %%
submission.to_csv(path + "submission/b45F_norm_epoch70_4_2.csv", index = False)

# %% [markdown]
# ## Efficientb4 모델 학습

# %% [markdown]
# 사전 학습 모델의 성능 파악을 할 때 Fold 학습은 실행 시간이 오래걸려서 fold를 나누지 않은 데이터에 대해서 학습을 진행하고 성능을 비교하였습니다.

# %%
batch_size = 32
epochs = 30

# Train
train_dataset = Custom_dataset(np.array(train_imgs), np.array(train_labels), np.array(train_classes), mode='train')
train_loader = DataLoader(train_dataset, shuffle=True, batch_size=batch_size)

# Test
test_dataset = Custom_dataset(np.array(test_imgs), np.array(["tmp"]*len(test_imgs)), np.array([]), mode='test')
test_loader = DataLoader(test_dataset, shuffle=False, batch_size=batch_size)

# %%
import gc
gc.collect()
torch.cuda.empty_cache()

# %%
def score_function(real, pred):
    score = f1_score(real, pred, average="macro")
    return score

model = Network().to(device)

# optimizer = torch.optim.AdamW(model.parameters(), lr=5e-5, weight_decay = 1e-3)
# optimizer = torch.optim.Adadelta(model.parameters(), weight_decay = 1e-3)
optimizer = torch.optim.Adadelta(model.parameters())
criterion = nn.CrossEntropyLoss()
scaler = torch.cuda.amp.GradScaler() 

batch_size = 32
epochs = 30

best=0
for epoch in range(epochs):
    start=time.time()
    train_loss = 0
    train_pred=[]
    train_y=[]
    model.train()
    for batch in (train_loader):
        optimizer.zero_grad()
        x = torch.tensor(batch[0], dtype=torch.float32, device=device)
        y = torch.tensor(batch[1], dtype=torch.long, device=device)
        with torch.cuda.amp.autocast():
            pred = model(x)
        loss = criterion(pred, y)


        scaler.scale(loss).backward()
        scaler.step(optimizer)
        scaler.update()
        
        train_loss += loss.item()/len(train_loader)
        train_pred += pred.argmax(1).detach().cpu().numpy().tolist()
        train_y += y.detach().cpu().numpy().tolist()
        
    
    train_f1 = score_function(train_y, train_pred)

    TIME = time.time() - start
    print(f'epoch : {epoch+1}/{epochs}    time : {TIME:.0f}s/{TIME*(epochs-epoch-1):.0f}s')
    print(f'TRAIN    loss : {train_loss:.5f}    f1 : {train_f1:.5f}')
# Out:
# Downloading: "https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-weights/efficientnet_b4_ra2_320-7eb33cd5.pth" to /root/.cache/torch/hub/checkpoints/efficientnet_b4_ra2_320-7eb33cd5.pth

# %% [markdown]
# ### 추론

# %%
model.eval()
f_pred = []
pred_prob = []

with torch.no_grad():
    for batch in (test_loader):
        x = torch.tensor(batch[0], dtype = torch.float32, device = device)
        with torch.cuda.amp.autocast():
            pred = model(x)
            pred_prob.extend(pred.detach().cpu().numpy())
        f_pred.extend(pred.argmax(1).detach().cpu().numpy().tolist())

# %%
label_decoder = {val:key for key, val in label_unique.items()}

f_result = [label_decoder[result] for result in f_pred]

# %% [markdown]
# ### 제출물 생성

# %%
submission = pd.read_csv(path + "data/sample_submission.csv")

submission["label"] = f_result

submission
# Out:
#       index             label
# 0         0   tile-glue_strip
# 1         1         grid-good
# 2         2   transistor-good
# 3         3  tile-gray_stroke
# 4         4         tile-good
# ...     ...               ...
# 2149   2149  tile-gray_stroke
# 2150   2150        screw-good
# 2151   2151         grid-good
# 2152   2152        cable-good
# 2153   2153       zipper-good
#
# [2154 rows x 2 columns]

# %%
# efficient b4, 30 epoch, adadelta, allflip
submission.to_csv(path + "submission/0512_b4_norm_30epoch_allflip.csv", index = False)
